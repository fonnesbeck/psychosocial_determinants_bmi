# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt

from functools import partial

from theano import shared, function, scan
import theano.tensor as tt
from theano.tensor import slinalg
from theano.tensor.nlinalg import matrix_inverse
cholesky = slinalg.cholesky

from pymc3 import Model, sample, Metropolis, advi, Deterministic, Mixture, generator
from pymc3 import DensityDist, CategoricalGibbsMetropolis, Minibatch, logsumexp
from pymc3.distributions import *
from pymc3.gp import cov, gp, mean
from pymc3 import ADVI, adam, fit, SVGD, sample_ppc, sgd
from pymc3 import forestplot, traceplot
from pymc3.theanof import floatX

DATA_DIR = '../data/clean/'

# %% [markdown]
# Sample of 5000 patients

# %%
bmi_by_patient = (pd.read_csv(DATA_DIR+'bmi_by_patient.csv', index_col=0)
                      .dropna(axis=1, thresh=5))
bmi_by_patient.head()
# Out:
#         1621101  1685338    1713205   1958537    2025534    2062537  \
# Days
# 0     27.464844      NaN  29.679341  27.51063  27.032689  27.484552
# 1           NaN      NaN        NaN       NaN        NaN        NaN
# 2           NaN      NaN        NaN       NaN        NaN        NaN
# 3           NaN      NaN        NaN       NaN        NaN        NaN
# 4           NaN      NaN        NaN       NaN        NaN        NaN
#
#         2087799    2129427    2186450    2382232    ...       40985475  \
# Days                                                ...
# 0     29.380994  27.614212  29.743767  28.201669    ...      27.777479
# 1           NaN        NaN        NaN        NaN    ...            NaN
# 2           NaN        NaN        NaN        NaN    ...            NaN
# 3           NaN        NaN        NaN        NaN    ...            NaN
# 4           NaN        NaN        NaN        NaN    ...            NaN
#
#        41005570   41014622  41014655   41043167   41052325  41054388  \
# Days
# 0     29.785761  28.921647       NaN  28.096818  28.663549  27.26058
# 1     29.785761        NaN       NaN        NaN        NaN       NaN
# 2     29.969401        NaN       NaN        NaN        NaN       NaN
# 3           NaN  29.030746       NaN        NaN        NaN       NaN
# 4           NaN        NaN       NaN        NaN        NaN       NaN
#
#        41077231   41087032   41248451
# Days
# 0     27.125971  27.423469  28.801188
# 1           NaN        NaN  28.695456
# 2           NaN        NaN  29.209745
# 3           NaN        NaN  28.695456
# 4           NaN        NaN        NaN
#
# [5 rows x 5915 columns]

# %%
assert bmi_by_patient.notnull().sum().min() == 5

# %%
bmi_by_patient.index =  pd.to_datetime(bmi_by_patient.index, unit='D')

# %%
bmi_resampled = bmi_by_patient.resample('2W').mean()
bmi_resampled.shape
# Out:
# (27, 5915)

# %%
# data_subset = bmi_resampled.iloc[:, :500]
data_subset = bmi_resampled.copy()

# %% [markdown]
# Random sample of 100 trajectories

# %%
fig, axes = plt.subplots(figsize=(14,6))
(bmi_resampled[np.random.choice(bmi_resampled.columns, 100)].interpolate(limit=10)
            .plot(legend=False, alpha=0.3, ax=axes))
axes.set_ylabel('BMI');

# %%
data_subset.shape
# Out:
# (27, 5915)

# %% [markdown]
# Stick-breaking function for Dirichlet process

# %%
def stick_breaking(beta):
    
    portion_remaining = tt.concatenate([[1], tt.extra_ops.cumprod(1 - beta)[:-1]])

    return beta * portion_remaining

# %% [markdown]
# Maximum number of groups

# %%
CLUSTERS = 20
D, N = data_subset.shape

# %%
data_missing = np.ma.masked_equal(data_subset.fillna(42).values, 42).T

# %%
data_missing.shape
# Out:
# (5915, 27)

# %%
APPROX = False

if APPROX:
    BATCH_SIZE = 10
    minibatches = Minibatch(data_missing, batch_size=BATCH_SIZE)
else:
    BATCH_SIZE = N
    minibatches = data_missing

X = np.arange(D).reshape(-1, 1)

# %%
with Model() as model:
        
    # DP concentration parameter
    α = Gamma('α', 1., 1.)
    # Stick-breaking components
    β = Beta('β', 1., 1, shape=CLUSTERS)
    ω = Deterministic('ω', stick_breaking(β))
    
    # GP indicators
    z = Categorical('z', ω, shape=N)
    
    # Hyperparameters of GPs
    η = HalfCauchy('η', 3, shape=CLUSTERS)
    ρ = HalfCauchy('ρ', 3, shape=CLUSTERS)
    # Noise
    σ = HalfCauchy('σ', 5)
    s_diag = tt.eye(D)*(σ**2)
    
    # Covariance functions for each component
    K = tt.stack([(η[c]**2)*cov.Matern32(1, ρ[c]**2)(X) for c in range(CLUSTERS)])
     
    
    def logp(value):
        return tt.sum([MvNormal.dist(tt.zeros_like(y), 
                            chol=cholesky(K[z[i]] + s_diag)).logp(y) for i,y in enumerate(value)])
        
    trajectories = DensityDist('trajectories', logp, observed=minibatches, 
                               shape=(BATCH_SIZE, D), total_size=data_missing.shape)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/theano/tensor/var.py in __iter__(self)
#     595         try:
# --> 596             for i in xrange(theano.tensor.basic.get_vector_length(self)):
#     597                 yield self[i]
#
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/theano/tensor/basic.py in get_vector_length(v)
#    4634         raise TypeError("argument must be symbolic vector, got '%s'" %
# -> 4635                         v)
#    4636     if v.type.broadcastable[0]:
#
# TypeError: argument must be symbolic vector, got 'AdvancedIncSubtensor{inplace=False,  set_instead_of_inc=True}.0'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-3c8b68e7d8a5> in <module>()
#      26
#      27     trajectories = DensityDist('trajectories', logp, observed=minibatches,
# ---> 28                                shape=(BATCH_SIZE, D), total_size=data_missing.shape)
#      29
#
# /Users/fonnescj/Repos/pymc3/pymc3/distributions/distribution.py in __new__(cls, name, *args, **kwargs)
#      37             total_size = kwargs.pop('total_size', None)
#      38             dist = cls.dist(*args, **kwargs)
# ---> 39             return model.Var(name, dist, data, total_size)
#      40         else:
#      41             raise TypeError("Name needs to be a string but got: {}".format(name))
#
# /Users/fonnescj/Repos/pymc3/pymc3/model.py in Var(self, name, dist, data, total_size)
#     543                 var = ObservedRV(name=name, data=data,
#     544                                  distribution=dist,
# --> 545                                  total_size=total_size, model=self)
#     546             self.observed_RVs.append(var)
#     547             if var.missing_values:
#
# /Users/fonnescj/Repos/pymc3/pymc3/model.py in __init__(self, type, owner, index, name, data, distribution, total_size, model)
#     968
#     969             self.missing_values = data.missing_values
# --> 970             self.logp_elemwiset = distribution.logp(data)
#     971             self.total_size = total_size
#     972             self.model = model
#
# <ipython-input-14-3c8b68e7d8a5> in logp(value)
#      23     def logp(value):
#      24         return tt.sum([MvNormal.dist(tt.zeros_like(y),
# ---> 25                             chol=cholesky(K[z[i]] + s_diag)).logp(y) for i,y in enumerate(value)])
#      26
#      27     trajectories = DensityDist('trajectories', logp, observed=minibatches,
#
# <ipython-input-14-3c8b68e7d8a5> in <listcomp>(.0)
#      22
#      23     def logp(value):
# ---> 24         return tt.sum([MvNormal.dist(tt.zeros_like(y),
#      25                             chol=cholesky(K[z[i]] + s_diag)).logp(y) for i,y in enumerate(value)])
#      26
#
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/theano/tensor/var.py in __iter__(self)
#     598         except TypeError:
#     599             # This prevents accidental iteration via builtin.sum(self)
# --> 600             raise TypeError(('TensorType does not support iteration. '
#     601                              'Maybe you are using builtin.sum instead of '
#     602                              'theano.tensor.sum? (Maybe .max?)'))
#
# TypeError: TensorType does not support iteration. Maybe you are using builtin.sum instead of theano.tensor.sum? (Maybe .max?)

# %%
with model:
    
    # Prediction over grid
    xgrid = np.linspace(0, 25)
    D_pred = squared_distance(xgrid, xgrid)
    D_off_diag = squared_distance(x, xgrid)
    
    # Covariance matrices for prediction
    Σ_pred = η_sq * T.exp(-ρ_sq * D_pred)
    Σ_off_diag = η_sq * T.exp(-ρ_sq * D_off_diag)
    
    # Posterior mean
    μ_post = Deterministic('μ_post', T.dot(T.dot(Σ_off_diag, matrix_inverse(Σ)), y))
    # Posterior covariance
    Σ_post = Deterministic('Σ_post', Σ_pred - T.dot(T.dot(Σ_off_diag, matrix_inverse(Σ)), Σ_off_diag.T))

# %%
with model:
    if APPROX:
        approx = fit(n=30000, method='fullrank_advi')
        trace = approx.sample(1000)
    else:
        trace = sample(1000, n_init=50000, burn=2000)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-1ae0114fc575> in <module>()
#       1 with model:
#       2     if APPROX:
# ----> 3         approx = fit(n=30000)
#       4         trace = approx.sample(1000)
#       5     else:
#
# /Users/fonnescj/Repos/pymc3/pymc3/variational/inference.py in fit(n, local_rv, method, model, random_seed, start, inf_kwargs, **kwargs)
#     753                         'or Inference instance' %
#     754                         set(_select.keys()))
# --> 755     return inference.fit(n, **kwargs)
#
# /Users/fonnescj/Repos/pymc3/pymc3/variational/inference.py in fit(self, n, score, callbacks, progressbar, **kwargs)
#     121             callbacks = []
#     122         score = self._maybe_score(score)
# --> 123         step_func = self.objective.step_function(score=score, **kwargs)
#     124         progress = tqdm.trange(n, disable=not progressbar)
#     125         if score:
#
# /Users/fonnescj/Repos/pymc3/pymc3/memoize.py in memoizer(*args, **kwargs)
#      14
#      15         if key not in cache:
# ---> 16             cache[key] = obj(*args, **kwargs)
#      17
#      18         return cache[key]
#
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/theano/configparser.py in res(*args, **kwargs)
#     115         def res(*args, **kwargs):
#     116             with self:
# --> 117                 return f(*args, **kwargs)
#     118         return res
#     119
#
# /Users/fonnescj/Repos/pymc3/pymc3/variational/opvi.py in step_function(self, obj_n_mc, tf_n_mc, obj_optimizer, test_optimizer, more_obj_params, more_tf_params, more_updates, more_replacements, total_grad_norm_constraint, score, fn_kwargs)
#     259         if score:
#     260             step_fn = theano.function(
# --> 261                 [], updates.loss, updates=updates, **fn_kwargs)
#     262         else:
#     263             step_fn = theano.function([], None, updates=updates, **fn_kwargs)
#
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/theano/compile/function.py in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     324                    on_unused_input=on_unused_input,
#     325                    profile=profile,
# --> 326                    output_keys=output_keys)
#     327     # We need to add the flag check_aliased inputs if we have any mutable or
#     328     # borrowed used defined inputs
#
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/theano/compile/pfunc.py in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input, output_keys)
#     484                          accept_inplace=accept_inplace, name=name,
#     485                          profile=profile, on_unused_input=on_unused_input,
# --> 486                          output_keys=output_keys)
#     487
#     488
#
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/theano/compile/function_module.py in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input, output_keys)
#    1792                    profile=profile,
#    1793                    on_unused_input=on_unused_input,
# -> 1794                    output_keys=output_keys).create(
#    1795             defaults)
#    1796
#
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/theano/compile/function_module.py in __init__(self, inputs, outputs, mode, accept_inplace, function_builder, profile, on_unused_input, fgraph, output_keys)
#    1472                         optimizer, inputs, outputs)
#    1473                 else:
# -> 1474                     optimizer_profile = optimizer(fgraph)
#    1475
#    1476                 end_optimizer = time.time()
#
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/theano/gof/opt.py in __call__(self, fgraph)
#      96
#      97         """
# ---> 98         return self.optimize(fgraph)
#      99
#     100     def add_requirements(self, fgraph):
#
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/theano/gof/opt.py in optimize(self, fgraph, *args, **kwargs)
#      85             orig = theano.tensor.basic.constant.enable
#      86             theano.tensor.basic.constant.enable = False
# ---> 87             ret = self.apply(fgraph, *args, **kwargs)
#      88         finally:
#      89             theano.tensor.basic.constant.enable = orig
#
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/theano/gof/opt.py in apply(self, fgraph)
#     233                 nb_nodes_before = len(fgraph.apply_nodes)
#     234                 t0 = time.time()
# --> 235                 sub_prof = optimizer.optimize(fgraph)
#     236                 l.append(float(time.time() - t0))
#     237                 sub_profs.append(sub_prof)
#
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/theano/gof/opt.py in optimize(self, fgraph, *args, **kwargs)
#      85             orig = theano.tensor.basic.constant.enable
#      86             theano.tensor.basic.constant.enable = False
# ---> 87             ret = self.apply(fgraph, *args, **kwargs)
#      88         finally:
#      89             theano.tensor.basic.constant.enable = orig
#
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/theano/gof/opt.py in apply(self, fgraph, start_from)
#    2415                 nb = change_tracker.nb_imported
#    2416                 t_opt = time.time()
# -> 2417                 sub_prof = gopt.apply(fgraph)
#    2418                 time_opts[gopt] += time.time() - t_opt
#    2419                 sub_profs.append(sub_prof)
#
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/theano/gof/opt.py in apply(self, fgraph)
#     233                 nb_nodes_before = len(fgraph.apply_nodes)
#     234                 t0 = time.time()
# --> 235                 sub_prof = optimizer.optimize(fgraph)
#     236                 l.append(float(time.time() - t0))
#     237                 sub_profs.append(sub_prof)
#
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/theano/gof/opt.py in optimize(self, fgraph, *args, **kwargs)
#      85             orig = theano.tensor.basic.constant.enable
#      86             theano.tensor.basic.constant.enable = False
# ---> 87             ret = self.apply(fgraph, *args, **kwargs)
#      88         finally:
#      89             theano.tensor.basic.constant.enable = orig
#
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/theano/scan_module/scan_opt.py in apply(self, fgraph)
#     226                                                                scan_op.Scan)]
#     227         for node in nodelist:
# --> 228             self.process_node(fgraph, node)
#     229
#     230     def process_node(self, fgraph, node):
#
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/theano/scan_module/scan_opt.py in process_node(self, fgraph, node)
#     374                 list(zip(node.outputs, nw_node.outputs)),
#     375                 remove=[node],
# --> 376                 reason='scanOp_pushout_nonseqs_ops')
#     377             return True
#     378         elif not to_keep_set:
#
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/theano/gof/toolbox.py in replace_all_validate_remove(self, fgraph, replacements, remove, reason, warn)
#     389
#     390         """
# --> 391         chk = fgraph.replace_all_validate(replacements, reason)
#     392         self._nodes_removed.update(remove)
#     393         for rm in remove:
#
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/theano/gof/toolbox.py in replace_all_validate(self, fgraph, replacements, reason, verbose)
#     338         for r, new_r in replacements:
#     339             try:
# --> 340                 fgraph.replace(r, new_r, reason=reason, verbose=False)
#     341             except Exception as e:
#     342                 msg = str(e)
#
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/theano/gof/fg.py in replace(self, r, new_r, reason, verbose)
#     507         for node, i in list(r.clients):  # copy the client list for iteration
#     508             assert (node == 'output' and self.outputs[i] is r) or (node.inputs[i] is r)
# --> 509             self.change_input(node, i, new_r, reason=reason)
#     510
#     511         # sometimes the following is triggered.  If you understand why, please explain to James.
#
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/theano/gof/fg.py in change_input(self, node, i, new_r, reason)
#     449             return
#     450
# --> 451         self.__import_r__(new_r, reason=reason)
#     452         self.__add_client__(new_r, (node, i))
#     453         self.__remove_client__(r, (node, i), reason=reason)
#
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/theano/gof/fg.py in __import_r__(self, variable, reason)
#     349         # Imports the owners of the variables
#     350         if variable.owner and variable.owner not in self.apply_nodes:
# --> 351                 self.__import__(variable.owner, reason=reason)
#     352         elif (variable.owner is None and
#     353                 not isinstance(variable, graph.Constant) and
#
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/theano/gof/fg.py in __import__(self, apply_node, check, reason)
#     399         for node in new_nodes:
#     400             assert node not in self.apply_nodes
# --> 401             self.__setup_node__(node)
#     402             self.apply_nodes.add(node)
#     403             if not hasattr(node.tag, 'imported_by'):
#
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/theano/gof/fg.py in __setup_node__(self, node)
#     212             raise Exception("%s is already owned by another fgraph" % node)
#     213         if (hasattr(node.op, 'view_map') and
# --> 214             not all(isinstance(view, (list, tuple))
#     215                     for view in itervalues(node.op.view_map))):
#     216             raise Exception("Op '%s' have a bad view map '%s',"
#
# KeyboardInterrupt:

# %%
traceplot(trace, varnames=['σ', 'α']);

# %%
forestplot(trace, varnames=['ω'])

# %%
forestplot(trace, varnames=['η'])

# %%
forestplot(trace, varnames=['ρ'])

# %%
with model:
    posterior_samples = sample_ppc(trace, 100, vars=[η, ρ, σ])
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 147.98it/s]

# %%
eta = posterior_samples['η']
sigma = posterior_samples['σ']
rho = posterior_samples['ρ']
