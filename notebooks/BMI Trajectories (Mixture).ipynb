# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt

from functools import partial

from theano import shared, function, scan
import theano.tensor as tt
from theano.tensor import slinalg
from theano.tensor.nlinalg import matrix_inverse
cholesky = slinalg.cholesky

from pymc3 import Model, sample, Metropolis, advi, Deterministic, Mixture, generator
from pymc3 import DensityDist, CategoricalGibbsMetropolis, Minibatch, logsumexp, Mixture
from pymc3.distributions import *
from pymc3.gp import cov, gp, mean
from pymc3 import ADVI, adam, fit, SVGD, sample_ppc, sgd
from pymc3 import forestplot, traceplot

DATA_DIR = '../data/clean/'

# %% [markdown]
# Sample of 5000 patients

# %%
bmi_by_patient = (pd.read_csv(DATA_DIR+'bmi_by_patient.csv', index_col=0)
                      .dropna(axis=1, thresh=5))
bmi_by_patient.head()
# Out:
#         1621101  1685338    1713205   1958537    2025534    2062537  \
# Days
# 0     27.464844      NaN  29.679341  27.51063  27.032689  27.484552
# 1           NaN      NaN        NaN       NaN        NaN        NaN
# 2           NaN      NaN        NaN       NaN        NaN        NaN
# 3           NaN      NaN        NaN       NaN        NaN        NaN
# 4           NaN      NaN        NaN       NaN        NaN        NaN
#
#         2087799    2129427    2186450    2382232    ...       40985475  \
# Days                                                ...
# 0     29.380994  27.614212  29.743767  28.201669    ...      27.777479
# 1           NaN        NaN        NaN        NaN    ...            NaN
# 2           NaN        NaN        NaN        NaN    ...            NaN
# 3           NaN        NaN        NaN        NaN    ...            NaN
# 4           NaN        NaN        NaN        NaN    ...            NaN
#
#        41005570   41014622  41014655   41043167   41052325  41054388  \
# Days
# 0     29.785761  28.921647       NaN  28.096818  28.663549  27.26058
# 1     29.785761        NaN       NaN        NaN        NaN       NaN
# 2     29.969401        NaN       NaN        NaN        NaN       NaN
# 3           NaN  29.030746       NaN        NaN        NaN       NaN
# 4           NaN        NaN       NaN        NaN        NaN       NaN
#
#        41077231   41087032   41248451
# Days
# 0     27.125971  27.423469  28.801188
# 1           NaN        NaN  28.695456
# 2           NaN        NaN  29.209745
# 3           NaN        NaN  28.695456
# 4           NaN        NaN        NaN
#
# [5 rows x 5915 columns]

# %%
assert bmi_by_patient.notnull().sum().min() == 5

# %%
bmi_by_patient.index =  pd.to_datetime(bmi_by_patient.index, unit='D')

# %%
bmi_resampled = bmi_by_patient.resample('2W').mean()
bmi_resampled.shape
# Out:
# (27, 5915)

# %%
# data_subset = bmi_resampled.iloc[:, :500]
data_subset = bmi_resampled.copy()

# %% [markdown]
# Random sample of 100 trajectories

# %%
fig, axes = plt.subplots(figsize=(14,6))
(bmi_resampled[np.random.choice(bmi_resampled.columns, 100)].interpolate(limit=10)
            .plot(legend=False, alpha=0.3, ax=axes))
axes.set_ylabel('BMI');

# %%
data_subset.shape
# Out:
# (27, 5915)

# %% [markdown]
# Stick-breaking function for Dirichlet process

# %%
def stick_breaking(beta):
    
    portion_remaining = tt.concatenate([[1], tt.extra_ops.cumprod(1 - beta)[:-1]])

    return beta * portion_remaining

# %% [markdown]
# Maximum number of groups

# %%
CLUSTERS = 20
D, N = data_subset.shape

# %%
data_missing = np.ma.masked_equal(data_subset.fillna(42).values, 42).T

# %%
data_missing.shape
# Out:
# (5915, 27)

# %%
APPROX = True

if APPROX:
    BATCH_SIZE = 10
    minibatches = Minibatch(data_missing, batch_size=BATCH_SIZE)
else:
    BATCH_SIZE = N
    minibatches = data_missing

X = np.arange(D).reshape(-1, 1)

# %%
with Model() as model:
        
    # DP concentration parameter
    α = Gamma('α', 1., 1.)
    # Stick-breaking components
    β = Beta('β', 1., 1, shape=CLUSTERS)
    ω = Deterministic('ω', stick_breaking(β))
    
    # Hyperparameters of GPs
    η = HalfCauchy('η', 3, shape=CLUSTERS)
    ρ = HalfCauchy('ρ', 3, shape=CLUSTERS)
    # Noise
    σ = HalfCauchy('σ', 5)
    
    # Covariance functions for each component
    s = tt.eye(D)*(σ**2)
    chol = [cholesky((η[c]**2)*cov.Matern32(1, ρ[c]**2)(X) + s) for c in range(CLUSTERS)]
    
    
    Mixture('trajectories', ω, 
            [MvNormal.dist(tt.zeros(D), chol=c) for c in chol], 
            observed=minibatches, 
            total_size=data_missing.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/fonnescj/Repos/pymc3/pymc3/distributions/mixture.py in _comp_logp(self, value)
#      81
# ---> 82             return comp_dists.logp(value_)
#      83         except AttributeError:
#
# AttributeError: 'list' object has no attribute 'logp'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-7ee22c995c8b> in <module>()
#      21             [MvNormal.dist(tt.zeros(D), chol=c) for c in chol],
#      22             observed=minibatches,
# ---> 23             total_size=data_missing.shape)
#      24
#
# /Users/fonnescj/Repos/pymc3/pymc3/distributions/distribution.py in __new__(cls, name, *args, **kwargs)
#      37             total_size = kwargs.pop('total_size', None)
#      38             dist = cls.dist(*args, **kwargs)
# ---> 39             return model.Var(name, dist, data, total_size)
#      40         else:
#      41             raise TypeError("Name needs to be a string but got: {}".format(name))
#
# /Users/fonnescj/Repos/pymc3/pymc3/model.py in Var(self, name, dist, data, total_size)
#     543                 var = ObservedRV(name=name, data=data,
#     544                                  distribution=dist,
# --> 545                                  total_size=total_size, model=self)
#     546             self.observed_RVs.append(var)
#     547             if var.missing_values:
#
# /Users/fonnescj/Repos/pymc3/pymc3/model.py in __init__(self, type, owner, index, name, data, distribution, total_size, model)
#     968
#     969             self.missing_values = data.missing_values
# --> 970             self.logp_elemwiset = distribution.logp(data)
#     971             self.total_size = total_size
#     972             self.model = model
#
# /Users/fonnescj/Repos/pymc3/pymc3/distributions/mixture.py in logp(self, value)
#     111         w = self.w
#     112
# --> 113         return bound(logsumexp(tt.log(w) + self._comp_logp(value), axis=-1).sum(),
#     114                      w >= 0, w <= 1, tt.allclose(w.sum(axis=-1), 1),
#     115                      broadcast_conditions=False)
#
# /Users/fonnescj/Repos/pymc3/pymc3/distributions/mixture.py in _comp_logp(self, value)
#      82             return comp_dists.logp(value_)
#      83         except AttributeError:
# ---> 84             return tt.stack([comp_dist.logp(value.T) for comp_dist in comp_dists],
#      85                             axis=1)
#      86
#
# /Users/fonnescj/Repos/pymc3/pymc3/distributions/mixture.py in <listcomp>(.0)
#      82             return comp_dists.logp(value_)
#      83         except AttributeError:
# ---> 84             return tt.stack([comp_dist.logp(value.T) for comp_dist in comp_dists],
#      85                             axis=1)
#      86
#
# /Users/fonnescj/Repos/pymc3/pymc3/distributions/multivariate.py in logp(self, value)
#     198             onedim = False
#     199
# --> 200         delta = value - mu
#     201
#     202         if self._cov_type == 'cov':
#
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/theano/tensor/var.py in __sub__(self, other)
#     145         # and the return value in that case
#     146         try:
# --> 147             return theano.tensor.basic.sub(self, other)
#     148         except (NotImplementedError, AsTensorError):
#     149             return NotImplemented
#
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/theano/gof/op.py in __call__(self, *inputs, **kwargs)
#     672                 thunk.outputs = [storage_map[v] for v in node.outputs]
#     673
# --> 674                 required = thunk()
#     675                 assert not required  # We provided all inputs
#     676
#
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/theano/gof/op.py in rval()
#     841
#     842         def rval():
# --> 843             fill_storage()
#     844             for o in node.outputs:
#     845                 compute_map[o][0] = True
#
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/theano/gof/cc.py in __call__(self)
#    1696                 print(self.error_storage, file=sys.stderr)
#    1697                 raise
# -> 1698             reraise(exc_type, exc_value, exc_trace)
#    1699
#    1700
#
# /Users/fonnescj/anaconda3/envs/dev/lib/python3.6/site-packages/six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
#     685             raise value.with_traceback(tb)
# --> 686         raise value
#     687
#     688 else:
#
# ValueError: Input dimension mis-match. (input[0].shape[1] = 10, input[1].shape[1] = 27)

# %%
with model:
    if APPROX:
        approx = fit(n=30000, method='fullrank_advi')
        trace = approx.sample(1000)
    else:
        trace = sample(1000, n_init=50000, burn=2000)

# %%
traceplot(trace, varnames=['σ', 'α']);

# %%
forestplot(trace, varnames=['ω'])

# %%
forestplot(trace, varnames=['η'])

# %%
forestplot(trace, varnames=['ρ'])

# %%
with model:
    posterior_samples = sample_ppc(trace, 100, vars=[η, ρ, σ])
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 147.98it/s]

# %%
eta = posterior_samples['η']
sigma = posterior_samples['σ']
rho = posterior_samples['ρ']
